# %% [markdown]
# # Ejercicio 04: Evaluación de un Sistema de Recuperación de Información
#
# El objetivo de este ejercicio es evaluar la efectividad de un sistema de recuperación de información utilizando métricas como *precisión, recall, F1-score, Mean Average Precision (MAP) y Normalized Discounted Cumulative Gain (nDCG)*.
#
# Seguirás los siguientes pasos:
#
#  ### Proporcionar un Conjunto de Datos:
#
# - **Corpus de Documentos:** Utiliza el corpus del ejercicio anterior o un nuevo conjunto de documentos.

# %%
#Librerias
import xml.etree.ElementTree as ET
import numpy as np

# %%
input_file_path = '/kaggle/input/03ranking-corpus/03ranking_corpus.xml'
xml_tree = ET.parse(input_file_path)
xml_root = xml_tree.getroot()

# Crear una lista para almacenar los documentos con sus metadatos
doc_metadata_list = []

# Iterar a través de cada elemento 'document' en el archivo XML
for doc in xml_root.findall('document'):
    document_id = doc.get('id')
    doc_title = doc.find('doc_title').text
    doc_keywords = doc.find('doc_keywords').text
    doc_author = doc.find('doc_author').text
    doc_date = doc.find('doc_date').text
    
    doc_metadata_list.append({
        'id': document_id,
        'doc_title': doc_title,
        'doc_keywords': doc_keywords,
        'doc_author': doc_author,
        'doc_date': doc_date
    })

# %%
# Mostrar el resultado
for document in doc_metadata_list:
    print(f"ID: {document['id']}")
    print(f"Title: {document['doc_title']}")
    print(f"Keywords: {document['doc_keywords']}")
    print(f"Author: {document['doc_author']}")
    print(f"Date: {document['doc_date']}")
    print("-" * 60)
# Out:
# ID: 1
# Title: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
# Keywords: telemedicina, salud crónica, tratamiento, tecnología médica
# Author: Dr. Juan Pérez
# Date: 2023-01-15
# ------------------------------------------------------------
# ID: 2
# Title: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
# Keywords: nutrición, rendimiento académico, salud mental, estudiantes
# Author: Dra. María López
# Date: 2023-02-10
# ------------------------------------------------------------
# ID: 3
# Title: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
# Keywords: amistad, bienestar estudiantil, campus, relaciones sociales
# Author: Miguel Rodríguez
# Date: 2023-03-05
# ------------------------------------------------------------
# ID: 4
# Title: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
# Keywords: bibliotecas universitarias, investigación, academia, recursos
# Author: Lucía Martínez
# Date: 2023-04-20
# ------------------------------------------------------------
# ID: 5
# Title: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
# Keywords: espacios verdes, campus universitario, concentración, estrés
# Author: Carlos Fernández
# Date: 2023-05-15
# ------------------------------------------------------------
# ID: 6
# Title: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
# Keywords: cultura universitaria, hábitos saludables, bienestar, estudiantes
# Author: Ana Sánchez
# Date: 2023-06-10
# ------------------------------------------------------------
# ID: 7
# Title: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
# Keywords: sueño, salud mental, rendimiento académico, universitarios
# Author: Javier Torres
# Date: 2023-07-25
# ------------------------------------------------------------
# ID: 8
# Title: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
# Keywords: apoyo familiar, apoyo social, bienestar emocional, estudiantes
# Author: Laura Gómez
# Date: 2023-08-30
# ------------------------------------------------------------
# ID: 9
# Title: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
# Keywords: hábitos de lectura, desarrollo cognitivo, jóvenes, adultos
# Author: Fernando Ruiz
# Date: 2023-09-18
# ------------------------------------------------------------
# ID: 10
# Title: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
# Keywords: tecnología médica, medicina preventiva, jóvenes, avances tecnológicos
# Author: Elena Navarro
# Date: 2023-10-05
# ------------------------------------------------------------
# ID: 11
# Title: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
# Keywords: ejercicio, estrés académico, estudiantes universitarios, salud
# Author: Diego Castro
# Date: 2023-11-12
# ------------------------------------------------------------
# ID: 12
# Title: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
# Keywords: mindfulness, meditación, ansiedad, estudiantes universitarios
# Author: Sofía Vega
# Date: 2023-12-01
# ------------------------------------------------------------
# ID: 13
# Title: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
# Keywords: salud mental, estudiantes universitarios, apoyo psicológico, grupos de estudio
# Author: Marcos Ortiz
# Date: 2024-01-10
# ------------------------------------------------------------
# ID: 14
# Title: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
# Keywords: salud mental, desempeño académico, servicios universitarios, estudiantes
# Author: Paula Morales
# Date: 2024-02-15
# ------------------------------------------------------------
# ID: 15
# Title: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
# Keywords: actividades extracurriculares, bienestar emocional, social, estudiantes
# Author: José Herrera
# Date: 2024-03-05
# ------------------------------------------------------------
# ID: 16
# Title: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
# Keywords: laboratorios de innovación, competencias tecnológicas, educación, desarrollo
# Author: Andrea Díaz
# Date: 2024-04-20
# ------------------------------------------------------------
# ID: 17
# Title: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
# Keywords: diseño de campus, interacción, colaboración, tendencias
# Author: Sergio Muñoz
# Date: 2024-05-15
# ------------------------------------------------------------
# ID: 18
# Title: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
# Keywords: bienestar académico, estudiantes que trabajan, comparación, rendimiento
# Author: Isabel Flores
# Date: 2024-06-10
# ------------------------------------------------------------
# ID: 19
# Title: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
# Keywords: agotamiento académico, factores de riesgo, prevención, estudiantes universitarios
# Author: Ricardo Ramos
# Date: 2024-07-25
# ------------------------------------------------------------
# ID: 20
# Title: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
# Keywords: tecnología, redes sociales, calidad del sueño, estudiantes
# Author: Valeria Castillo
# Date: 2024-08-30
# ------------------------------------------------------------
# ID: 21
# Title: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
# Keywords: tecnologías verdes, edificios universitarios, impacto ambiental, sostenibilidad
# Author: Daniel Medina
# Date: 2024-09-18
# ------------------------------------------------------------
# ID: 22
# Title: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
# Keywords: bicicletas compartidas, movilidad, universidades, transporte sostenible
# Author: Patricia Reyes
# Date: 2024-10-05
# ------------------------------------------------------------
# ID: 23
# Title: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
# Keywords: carga académica, salud emocional, estudiantes, apoyo universitario
# Author: Gonzalo Soto
# Date: 2024-11-12
# ------------------------------------------------------------
# ID: 24
# Title: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
# Keywords: equilibrio, vida social, académica, estudiantes, estrategias
# Author: Camila Aguilar
# Date: 2024-12-01
# ------------------------------------------------------------
# ID: 25
# Title: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
# Keywords: actividades artísticas, bienestar psicológico, vida universitaria, creatividad
# Author: Adrián Vargas
# Date: 2025-01-10
# ------------------------------------------------------------
# ID: 26
# Title: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
# Keywords: programas de becas, retención de estudiantes, beneficios, universidades
# Author: Teresa Romero
# Date: 2025-02-15
# ------------------------------------------------------------
# ID: 27
# Title: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
# Keywords: deportes, actividad física, integración social, estudiantes
# Author: Alberto Peña
# Date: 2025-03-05
# ------------------------------------------------------------
# ID: 28
# Title: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
# Keywords: eventos de bienestar, talleres, reducción del estrés, universidad
# Author: Silvia Campos
# Date: 2025-04-20
# ------------------------------------------------------------
# ID: 29
# Title: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
# Keywords: hábitos de sueño, rendimiento en exámenes, análisis, estudiantes
# Author: Óscar Luna
# Date: 2025-05-15
# ------------------------------------------------------------
# ID: 30
# Title: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
# Keywords: inteligencia artificial, servicios médicos, comunidades remotas, tecnología
# Author: María Paredes
# Date: 2025-06-10
# ------------------------------------------------------------

# %% [markdown]
# - **Consultas:** Define un conjunto de consultas específicas.

# %%
# Definir las consultas
query_dict = {
    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",
    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",
    3: "Estrategias universitarias para reducir el estrés en estudiantes"
}

# %% [markdown]
# - **Juicios de Relevancia:** Proporciona una lista de qué documentos son relevantes para cada consulta.

# %%
# Función para procesar el texto y extraer palabras clave
def text_processor(text):
    # Convertir a minúsculas
    text = text.lower()
    # Reemplazar caracteres no alfanuméricos por espacios
    import re
    text = re.sub(r'[^a-záéíóúñü]+', ' ', text)
    # Tokenizar y eliminar palabras vacías si es necesario
    tokens = text.strip().split()
    return set(tokens)

# %%
# Mostrar las palabras clave extraídas
for query_id, query_text in query_dict.items():
    # Procesar el texto de la consulta
    doc_keywords = text_processor(query_text)
    print(f"Consulta {query_id}: {doc_keywords}")
# Out:
# Consulta 1: {'impacto', 'salud', 'estudiantes', 'académico', 'de', 'el', 'mental', 'en', 'la', 'universitarios', 'rendimiento', 'los'}
# Consulta 2: {'campus', 'el', 'bienestar', 'emocional', 'y', 'en', 'universitario', 'extracurriculares', 'actividades'}
# Consulta 3: {'estudiantes', 'universitarias', 'para', 'estrés', 'reducir', 'el', 'en', 'estrategias'}

# %%
# Función de similitud coseno
def cosine_similarity(query, doc):
    query_tokens = text_processor(query)
    doc_tokens = text_processor(doc)

    # Crear el vocabulario (todas las palabras únicas en la consulta y el documento)
    vocabulary = list(query_tokens | doc_tokens)  # Unión de los conjuntos

    # Crear los vectores de frecuencia (binarios)
    query_vector = [1 if word in query_tokens else 0 for word in vocabulary]
    doc_vector = [1 if word in doc_tokens else 0 for word in vocabulary]

    # Calcular el producto punto y las normas
    dot_product = np.dot(query_vector, doc_vector)
    norm_query = np.linalg.norm(query_vector)
    norm_doc = np.linalg.norm(doc_vector)

    # Similitud coseno
    if norm_query == 0 or norm_doc == 0:
        return 0  # No hay similitud si uno de los vectores es cero
    return dot_product / (norm_query * norm_doc)

# %%
# Función de similitud de Jaccard
def jaccard_similarity(query, doc):
    query_tokens = text_processor(query)
    doc_tokens = text_processor(doc)

    # Intersección y unión de los conjuntos
    intersection = query_tokens & doc_tokens
    union = query_tokens | doc_tokens
    return len(intersection) / len(union)

# %%
# Uso de la similaridad del coseno
for query_id, query_text in query_dict.items():
    print(f"Consulta {query_id}: {query_text}")
    
    for doc in doc_metadata_list:
        doc_text = doc['doc_title'] + ' ' + doc['doc_keywords'] 
        cosine_score = cosine_similarity(query_text, doc_text) 
        
        print(f"  Documento {doc['id']}: {doc['doc_title']}")
        print(f"    Similitud Coseno: {cosine_score:.4f}")
    print("\n")
# Out:
# Consulta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.3203
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.6405
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.3501
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.3203
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.3608
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.4804
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.6405
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.5217
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.4167
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1601
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.6172
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.4804
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.5809
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.6301
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.3203
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.3333
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.3203
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.3727
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.4629
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.4629
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.4472
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.2981
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.3693
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.2402
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.2402
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.4352
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.4629
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2722
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.5217
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.2236
#
#
# Consulta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.0925
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.2774
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.3234
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.1849
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.4167
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.3698
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.2774
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.4303
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.2887
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1849
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.0891
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.2774
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.2981
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.1617
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.5547
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.1925
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.3698
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.3443
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.2673
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.2673
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.1721
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.1721
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.2132
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.1849
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.4623
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.1005
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.3563
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2357
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.2582
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.1721
#
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.1961
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.2942
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.2572
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.2942
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.3536
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.2942
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.1961
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.2739
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.2041
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1961
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.2835
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.2942
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.3953
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.2572
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.2942
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.2041
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.2942
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.2739
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.4725
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.2835
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.1826
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.2739
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.1508
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.3922
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.1961
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.3198
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.2835
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2500
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.2739
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.1826

# %%
# Uso de la similaridad de Jaccard
for query_id, query_text in query_dict.items():
    print(f"Consulta {query_id}: {query_text}")
    
    for doc in doc_metadata_list:
        doc_text = doc['doc_title'] + ' ' + doc['doc_keywords'] 
        jaccard_score = jaccard_similarity(query_text, doc_text) # Aplicamos el método para calcular la similaridad de Jaccard
        
        print(f"  Documento {doc['id']}: {doc['doc_title']}")
        print(f"    Similitud de Jaccard: {jaccard_score:.4f}")
    print("\n")
# Out:
# Consulta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud de Jaccard: 0.1905
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud de Jaccard: 0.4706
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud de Jaccard: 0.2083
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud de Jaccard: 0.1905
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud de Jaccard: 0.2174
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud de Jaccard: 0.3158
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud de Jaccard: 0.4706
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud de Jaccard: 0.3500
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud de Jaccard: 0.2632
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud de Jaccard: 0.0870
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.4444
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud de Jaccard: 0.3158
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud de Jaccard: 0.3913
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud de Jaccard: 0.4500
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud de Jaccard: 0.1905
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud de Jaccard: 0.2000
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud de Jaccard: 0.1905
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud de Jaccard: 0.2273
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.3000
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud de Jaccard: 0.3000
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud de Jaccard: 0.2857
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud de Jaccard: 0.1739
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud de Jaccard: 0.2143
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud de Jaccard: 0.1364
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud de Jaccard: 0.1364
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud de Jaccard: 0.2778
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud de Jaccard: 0.3000
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud de Jaccard: 0.1538
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud de Jaccard: 0.3500
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud de Jaccard: 0.1250
#
#
# Consulta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud de Jaccard: 0.0476
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud de Jaccard: 0.1579
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud de Jaccard: 0.1818
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud de Jaccard: 0.1000
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud de Jaccard: 0.2500
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud de Jaccard: 0.2222
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud de Jaccard: 0.1579
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud de Jaccard: 0.2632
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud de Jaccard: 0.1667
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud de Jaccard: 0.1000
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.0455
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud de Jaccard: 0.1579
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud de Jaccard: 0.1600
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud de Jaccard: 0.0833
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud de Jaccard: 0.3750
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud de Jaccard: 0.1053
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud de Jaccard: 0.2222
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud de Jaccard: 0.2000
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.1500
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud de Jaccard: 0.1500
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud de Jaccard: 0.0909
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud de Jaccard: 0.0909
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud de Jaccard: 0.1071
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud de Jaccard: 0.1000
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud de Jaccard: 0.2941
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud de Jaccard: 0.0526
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud de Jaccard: 0.2105
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud de Jaccard: 0.1250
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud de Jaccard: 0.1429
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud de Jaccard: 0.0909
#
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud de Jaccard: 0.1053
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud de Jaccard: 0.1667
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud de Jaccard: 0.1364
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud de Jaccard: 0.1667
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud de Jaccard: 0.2000
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud de Jaccard: 0.1667
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud de Jaccard: 0.1053
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud de Jaccard: 0.1500
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud de Jaccard: 0.1111
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud de Jaccard: 0.1053
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.1579
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud de Jaccard: 0.1667
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud de Jaccard: 0.2174
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud de Jaccard: 0.1364
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud de Jaccard: 0.1667
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud de Jaccard: 0.1111
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud de Jaccard: 0.1667
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud de Jaccard: 0.1500
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud de Jaccard: 0.2941
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud de Jaccard: 0.1579
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud de Jaccard: 0.0952
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud de Jaccard: 0.1500
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud de Jaccard: 0.0714
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud de Jaccard: 0.2353
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud de Jaccard: 0.1053
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud de Jaccard: 0.1875
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud de Jaccard: 0.1579
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud de Jaccard: 0.1304
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud de Jaccard: 0.1500
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud de Jaccard: 0.0952

# %% [markdown]
#  ### Calcular Resultados de Búsqueda:
#
# - Obten los resultados ordenados de dos sistemas de recuperación para cada consulta.

# %%
# Número de documentos a mostrar
k = 10

# Función para rankear los documentos
def rank_documents(query_dict, similarity_function):
    rankings = {}
    
    for query_id, query_text in query_dict.items():
        similarity_scores = []
        
        # Calcular la similitud de cada documento con la consulta
        for doc in doc_metadata_list:
            doc_text = doc['doc_title'] + ' ' + doc['doc_keywords']
            similarity_score = similarity_function(query_text, doc_text)
            similarity_scores.append((doc['id'], doc['doc_title'], similarity_score))
        
        # Ordenar los documentos por la similitud (de mayor a menor)
        ranked_docs = sorted(similarity_scores, key=lambda x: x[2], reverse=True)
        
        # Guardar los k primeros documentos
        rankings[query_id] = ranked_docs[:k]
    
    return rankings

# %%
# Rankear los documentos usando la similitud coseno
cosine_rankings = rank_documents(query_dict, cosine_similarity)

# Mostrar los rankings
print("Ranking por Similitud Coseno:")
for query_id, ranked_docs in cosine_rankings.items():
    print(f"Consulta {query_id}: {query_text}")
    for rank, (document_id, doc_title, score) in enumerate(ranked_docs, start=1):
        print(f" {rank}. Documento {document_id} - (Similitud Coseno: {score:.4f})")
        print(f" {doc_title}")
    print("\n")
# Out:
# Ranking por Similitud Coseno:
# Consulta 1: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 2 - (Similitud Coseno: 0.6405)
#  Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#  2. Documento 7 - (Similitud Coseno: 0.6405)
#  La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#  3. Documento 14 - (Similitud Coseno: 0.6301)
#  Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#  4. Documento 11 - (Similitud Coseno: 0.6172)
#  Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#  5. Documento 13 - (Similitud Coseno: 0.5809)
#  Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#  6. Documento 8 - (Similitud Coseno: 0.5217)
#  La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#  7. Documento 29 - (Similitud Coseno: 0.5217)
#  Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#  8. Documento 6 - (Similitud Coseno: 0.4804)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  9. Documento 12 - (Similitud Coseno: 0.4804)
#  El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#  10. Documento 19 - (Similitud Coseno: 0.4629)
#  Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#
#
# Consulta 2: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 15 - (Similitud Coseno: 0.5547)
#  Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#  2. Documento 25 - (Similitud Coseno: 0.4623)
#  La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#  3. Documento 8 - (Similitud Coseno: 0.4303)
#  La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#  4. Documento 5 - (Similitud Coseno: 0.4167)
#  Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#  5. Documento 6 - (Similitud Coseno: 0.3698)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  6. Documento 17 - (Similitud Coseno: 0.3698)
#  Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#  7. Documento 27 - (Similitud Coseno: 0.3563)
#  El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#  8. Documento 18 - (Similitud Coseno: 0.3443)
#  Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#  9. Documento 3 - (Similitud Coseno: 0.3234)
#  Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#  10. Documento 13 - (Similitud Coseno: 0.2981)
#  Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 19 - (Similitud Coseno: 0.4725)
#  Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#  2. Documento 13 - (Similitud Coseno: 0.3953)
#  Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#  3. Documento 24 - (Similitud Coseno: 0.3922)
#  Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#  4. Documento 5 - (Similitud Coseno: 0.3536)
#  Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#  5. Documento 26 - (Similitud Coseno: 0.3198)
#  Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#  6. Documento 2 - (Similitud Coseno: 0.2942)
#  Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#  7. Documento 4 - (Similitud Coseno: 0.2942)
#  El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#  8. Documento 6 - (Similitud Coseno: 0.2942)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  9. Documento 12 - (Similitud Coseno: 0.2942)
#  El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#  10. Documento 15 - (Similitud Coseno: 0.2942)
#  Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.

# %%
# Rankear los documentos usando la similitud de Jaccard
jaccard_rankings = rank_documents(query_dict, jaccard_similarity)

# Mostrar los rankings
print("Ranking por Similitud de Jaccard:")
for query_id, ranked_docs in jaccard_rankings.items():
    print(f"Consulta {query_id}: {query_text}")
    for rank, (document_id, doc_title, score) in enumerate(ranked_docs, start=1):
        print(f" {rank}. Documento {document_id} - (Similitud Jaccard: {score:.4f})")
        print(f" {doc_title}")
    print("\n")
# Out:
# Ranking por Similitud de Jaccard:
# Consulta 1: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 2 - (Similitud Jaccard: 0.4706)
#  Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#  2. Documento 7 - (Similitud Jaccard: 0.4706)
#  La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#  3. Documento 14 - (Similitud Jaccard: 0.4500)
#  Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#  4. Documento 11 - (Similitud Jaccard: 0.4444)
#  Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#  5. Documento 13 - (Similitud Jaccard: 0.3913)
#  Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#  6. Documento 8 - (Similitud Jaccard: 0.3500)
#  La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#  7. Documento 29 - (Similitud Jaccard: 0.3500)
#  Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#  8. Documento 6 - (Similitud Jaccard: 0.3158)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  9. Documento 12 - (Similitud Jaccard: 0.3158)
#  El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#  10. Documento 19 - (Similitud Jaccard: 0.3000)
#  Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#
#
# Consulta 2: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 15 - (Similitud Jaccard: 0.3750)
#  Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#  2. Documento 25 - (Similitud Jaccard: 0.2941)
#  La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#  3. Documento 8 - (Similitud Jaccard: 0.2632)
#  La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#  4. Documento 5 - (Similitud Jaccard: 0.2500)
#  Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#  5. Documento 6 - (Similitud Jaccard: 0.2222)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  6. Documento 17 - (Similitud Jaccard: 0.2222)
#  Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#  7. Documento 27 - (Similitud Jaccard: 0.2105)
#  El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#  8. Documento 18 - (Similitud Jaccard: 0.2000)
#  Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#  9. Documento 3 - (Similitud Jaccard: 0.1818)
#  Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#  10. Documento 9 - (Similitud Jaccard: 0.1667)
#  El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
#  1. Documento 19 - (Similitud Jaccard: 0.2941)
#  Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#  2. Documento 24 - (Similitud Jaccard: 0.2353)
#  Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#  3. Documento 13 - (Similitud Jaccard: 0.2174)
#  Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#  4. Documento 5 - (Similitud Jaccard: 0.2000)
#  Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#  5. Documento 26 - (Similitud Jaccard: 0.1875)
#  Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#  6. Documento 2 - (Similitud Jaccard: 0.1667)
#  Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#  7. Documento 4 - (Similitud Jaccard: 0.1667)
#  El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#  8. Documento 6 - (Similitud Jaccard: 0.1667)
#  La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#  9. Documento 12 - (Similitud Jaccard: 0.1667)
#  El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#  10. Documento 15 - (Similitud Jaccard: 0.1667)
#  Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.

# %% [markdown]
#  ### Calcular las Métricas de Evaluación:
#
# - Calcular las siguientes métricas para cada sistema y consulta:
# -
#   - Precisión en el top-k (Prec@k)
#   -
# Recal
#   -
# F1-sco
#   - e
# Mean Average Precision (M
#   - P)
# nDCG

# %%
# Función para determinar si un documento es relevante según el umbral
def is_relevant(score, threshold):
    return score >= threshold

# Función para calcular la precisión en el top-k
def precision_at_k(ranked_scores, k):
    relevant_docs = sum([1 for score in ranked_scores[:k] if score[1]])
    return relevant_docs / k

# Función para calcular el recall
def recall(ranked_scores, total_relevant_docs):
    relevant_retrieved = sum([1 for score in ranked_scores if score[1]])
    return relevant_retrieved / total_relevant_docs if total_relevant_docs > 0 else 0

# Función para calcular F1-score
def f1_score(precision, recall):
    return (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Función para calcular Mean Average Precision (MAP)
def mean_average_precision(ranked_scores):
    relevant_docs = 0
    sum_precisions = 0
    for i, (score, is_rel) in enumerate(ranked_scores):
        if is_rel:
            relevant_docs += 1
            sum_precisions += relevant_docs / (i + 1)
    return sum_precisions / relevant_docs if relevant_docs > 0 else 0

# Función para calcular nDCG
def ndcg(ranked_scores, k):
    dcg = sum([score[1] / np.log2(i + 2) for i, score in enumerate(ranked_scores[:k])])
    ideal_scores = sorted([score[1] for score in ranked_scores], reverse=True)[:k]
    idcg = sum([rel / np.log2(i + 2) for i, rel in enumerate(ideal_scores)])
    return dcg / idcg if idcg > 0 else 0

# %%
# Definimos el umbral de relevancia mínimo
relevance_threshold_cos = 0.47 # Valor dado luego del análisis del ranking
relevance_threshold_jac = 0.29 # Valor dado luego del análisis del ranking

# Función para obtener las métricas para cada sistema y consulta
def evaluate_similarity_cos(query_dict, doc_metadata_list, similarity_func):
    results = {}
    for query_id, query_text in query_dict.items():
        ranked_docs = []
        
        # Calcular la similitud para cada documento
        for doc in doc_metadata_list:
            doc_text = doc['doc_title'] + ' ' + doc['doc_keywords']
            score = similarity_func(query_text, doc_text)
            is_rel = is_relevant(score, relevance_threshold_cos)
            ranked_docs.append((score, is_rel))
        
        # Ordenar documentos por similitud en orden descendente
        ranked_docs.sort(reverse=True, key=lambda x: x[0])
        
        # Calcular métricas de evaluación
        total_relevant_docs = sum([is_rel for _, is_rel in ranked_docs])  # Número de documentos relevantes
        prec_k = precision_at_k(ranked_docs, k)
        rec = recall(ranked_docs, total_relevant_docs)
        f1 = f1_score(prec_k, rec)
        map_score = mean_average_precision(ranked_docs)
        ndcg_score = ndcg(ranked_docs, k)
        
        # Guardar resultados
        results[query_id] = {
            'Prec@k': prec_k,
            'Recall': rec,
            'F1-score': f1,
            'MAP': map_score,
            'nDCG': ndcg_score
        }
    
    return results

def evaluate_similarity_jac(query_dict, doc_metadata_list, similarity_func):
    results = {}
    for query_id, query_text in query_dict.items():
        ranked_docs = []
        
        # Calcular la similitud para cada documento
        for doc in doc_metadata_list:
            doc_text = doc['doc_title'] + ' ' + doc['doc_keywords']
            score = similarity_func(query_text, doc_text)
            is_rel = is_relevant(score, relevance_threshold_jac)
            ranked_docs.append((score, is_rel))
        
        # Ordenar documentos por similitud en orden descendente
        ranked_docs.sort(reverse=True, key=lambda x: x[0])
        
        # Calcular métricas de evaluación
        total_relevant_docs = sum([is_rel for _, is_rel in ranked_docs])  # Número de documentos relevantes
        prec_k = precision_at_k(ranked_docs, k)
        rec = recall(ranked_docs, total_relevant_docs)
        f1 = f1_score(prec_k, rec)
        map_score = mean_average_precision(ranked_docs)
        ndcg_score = ndcg(ranked_docs, k)
        
        # Guardar resultados
        results[query_id] = {
            'Prec@k': prec_k,
            'Recall': rec,
            'F1-score': f1,
            'MAP': map_score,
            'nDCG': ndcg_score
        }
    
    return results

# %% [markdown]
#  ### Análisis y Comparación:
#
# - Comparar los resultados de los dos sistemas utilizando las métricas calculadas.

# %%
# Evaluación y comparación de resultados
cosine_results = evaluate_similarity_cos(query_dict, doc_metadata_list, cosine_similarity)

# Mostrar resultados
for query_id in query_dict:
    print(f"\nConsulta {query_id}: {query_dict[query_id]}")
    print("Métricas para la Similitud Coseno:")
    print(f"  Precisión en el top-k Prec@{k}: {cosine_results[query_id]['Prec@k']:.4f}")
    print(f"  Recall: {cosine_results[query_id]['Recall']:.4f}")
    print(f"  F1-score: {cosine_results[query_id]['F1-score']:.4f}")
    print(f"  Mean Average Precision MAP: {cosine_results[query_id]['MAP']:.4f}")
    print(f"  nDCG@{k}: {cosine_results[query_id]['nDCG']:.4f}")
# Out:
# Consulta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
# Métricas para la Similitud Coseno:
#   Precisión en el top-k Prec@10: 0.9000
#   Recall: 1.0000
#   F1-score: 0.9474
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000
#
# Consulta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
# Métricas para la Similitud Coseno:
#   Precisión en el top-k Prec@10: 0.1000
#   Recall: 1.0000
#   F1-score: 0.1818
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
# Métricas para la Similitud Coseno:
#   Precisión en el top-k Prec@10: 0.1000
#   Recall: 1.0000
#   F1-score: 0.1818
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000

# %%
# Mostrar resultados
jaccard_results = evaluate_similarity_jac(query_dict, doc_metadata_list, jaccard_similarity)

# Mostrar resultados
for query_id in query_dict:
    print(f"\nConsulta {query_id}: {query_dict[query_id]}")
    print("Métricas para la Similitud Jaccard:")
    print(f"  Precisión en el top-k Prec@{k}: {jaccard_results[query_id]['Prec@k']:.4f}")
    print(f"  Recall: {jaccard_results[query_id]['Recall']:.4f}")
    print(f"  F1-score: {jaccard_results[query_id]['F1-score']:.4f}")
    print(f"  Mean Average Precision MAP: {jaccard_results[query_id]['MAP']:.4f}")
    print(f"  nDCG@{k}: {jaccard_results[query_id]['nDCG']:.4f}")
# Out:
# Consulta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
# Métricas para la Similitud Jaccard:
#   Precisión en el top-k Prec@10: 1.0000
#   Recall: 1.0000
#   F1-score: 1.0000
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000
#
# Consulta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
# Métricas para la Similitud Jaccard:
#   Precisión en el top-k Prec@10: 0.2000
#   Recall: 1.0000
#   F1-score: 0.3333
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
# Métricas para la Similitud Jaccard:
#   Precisión en el top-k Prec@10: 0.1000
#   Recall: 1.0000
#   F1-score: 0.1818
#   Mean Average Precision MAP: 1.0000
#   nDCG@10: 1.0000

# %% [markdown]
#  ### Análisis y Comparación:
#
# - Discutir cuál sistema es más efectivo y por qué.

# %% [markdown]
#  ### Comparación entre consultas:
#
# - **Consulta 1:** Jaccard logra una precisión de 1.0 frente al 0.9 de Coseno, lo que sugiere que Jaccard es ligeramente mejor en esta consulta.
# - **Consulta 2:** Jaccard supera a Coseno en esta consulta, con una Prec@10 de 0.2 frente a 0.1 en Coseno, y un F1-score más alto con un valor de 0.33 frente a 0.18 en Coseno.
# - **Consulta 3:** Ambas técnicas arrojan resultados idénticos.
#
#  ### Conclusión:
#
# La técnica de Similitud Jaccard es ligeramente más efectiva que Coseno para estas consultas, ya que obtuvo mejor precisión y F1-score en la Consulta 1 y significativamente mejor en la Consulta 2, sin perder recall en ningún caso. Esto sugiere que Jaccard es más precisa al identificar documentos relevantes.
