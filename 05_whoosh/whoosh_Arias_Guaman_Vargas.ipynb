# %%
# !pip install whoosh
# Out:
# Requirement already satisfied: whoosh in /usr/local/lib/python3.10/dist-packages (2.7.4)

# %%
# !pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.10/dist-packages (8.17.0)
# Requirement already satisfied: elastic-transport<9,>=8.15.1 in /usr/local/lib/python3.10/dist-packages (from elasticsearch) (8.17.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch) (2024.12.14)

# %%
# Importar las bibliotecas necesarias
import pandas as pd
import re
from collections import defaultdict
from whoosh.fields import Schema, TEXT
from whoosh.index import create_in, open_dir
from whoosh.qparser import QueryParser
from whoosh import index
import os
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk

# Cargar el archivo CSV
file_path = '/content/wiki_movie_plots_deduped.csv'  # Cambia esto si el archivo está en otro directorio
data = pd.read_csv(file_path)

# Filtrar columnas relevantes
data = data[['Title', 'Plot']].dropna()

# Normalizar texto: convertir a minúsculas y eliminar caracteres especiales
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text

data['Plot'] = data['Plot'].apply(normalize_text)

# %%
# Construcción del índice invertido
def build_manual_index(data):
    index = defaultdict(list)
    for idx, row in data.iterrows():
        title = row['Title']
        plot = row['Plot']
        for word in plot.split():
            index[word].append(title)
    return index

# Normalizar texto (puedes personalizar esta función si usas lematización, stemming, etc.)
def normalize_text(text):
    return text.lower()  # Convertir a minúsculas

# Función para realizar consultas en el índice invertido
def search_manual_index(query, index):
    query = normalize_text(query)
    words = query.split()
    results = set(index[words[0]])
    for word in words[1:]:
        results.intersection_update(index[word])
    return results

# %%
# Construcción del índice a partir de los datos
index = build_manual_index(data)

# Verificar el índice construido
print(f"Índice invertido construido con {len(index)} palabras.")
# Out:
# Índice invertido construido con 181327 palabras.

# %%
# Ejemplo de consulta 1
query = "man"
print("Películas encontradas:", search_manual_index(query, index))
# Out:
# Películas encontradas: {'Malice', 'The Matrix', 'River of No Return', 'The Awaken Punch', 'Daasi', 'Canyon Passage', 'Katha', 'Metropolis', 'The Brave', 'Bahurani', 'Dahleez', 'Passage to Marseille', 'Go Tell the Spartans', 'Boy on a Dolphin', 'Parda Hai Parda', 'Frankenstein Meets the Wolf Man', 'Gaslight', 'My One and Only', "Brewster's Millions", 'The Man Is Armed', 'Life During Wartime', 'The Evening Star', 'The Birdcage', 'The Reivers', 'Jailhouse Rock', 'Trojan War', 'The Little Convict', 'Captain Ron', 'Chill Factor', 'Vaastav: The Reality', ' Love of My Life', 'Miss You Like Crazy', 'War on Everyone', 'Cool Hand Luke', 'Flaming Feather', 'Texas Carnival', 'Norwegian Wood', 'Dance, Girl, Dance', 'Chitra', 'The Old Maid', 'My Young Auntie', 'Ardhangi', 'Actress', 'Comedy, TheThe Comedy', ' Berlin Syndrome', 'Immortal Sergeant', 'Enduring Love', 'So Long Mr. Chumps', 'Casual Sex?', 'Courier Boy Kalyan', 'The First Born', 'Waaris', 'Dedh Ishqiya', 'Catacombs', 'Mutiny on the Bounty', 'Kung Fu Hustle', 'Shukriya: Till Death Do Us Apart', 'Frozen Ground, TheThe Frozen Ground', 'Metalstorm: The Destruction of Jared-Syn', 'Apparition, TheThe Apparition', 'Kan Simittum Neram', 'West of Shanghai', 'The Magic Riddle', 'Broken Strings', 'Bus Stop', 'Vaana', "Love's Brother", 'Sirens', 'With Honors', 'Her Right to Live', 'Seepeeyan', 'In Love and War', 'Looking for Mr. Goodbar', 'Chained Heat II', 'Highway', 'Margin for Error', 'Crouching Tiger, Hidden Dragon: Sword of Destiny', 'Circus World', 'War Arrow', 'Confession of Murder (a.k.a. Memoirs of a Murderer)', 'Chakra', 'Gejje Pooje', 'Thoroughly Modern Millie', 'Patita', 'I Was a Teenage Werewolf', 'City Under Siege', 'The Phantom Tollbooth', 'Untamed', 'Potugadu', "Straight A's", 'Billy the Kid and the Green Baize Vampire', 'Fifty Roads to Town', 'Dus Kahaniyaan', 'The Road to Sampo', 'The Reluctant Fundamentalist', 'Joshilaay', 'Creepshow 2', 'Aadavantha Deivam', 'The Scorpion King', 'Nurse 3D', 'Vellimoonga', "You Can't Buy Everything", 'The Silver Lining', 'War, Inc.', 'Nalla Kaalam Porandaachu', 'No Retreat, No Surrender 2', 'The Savages', 'Munna Bhai M.B.B.S.', 'Pacific Destiny', 'Himalaya Singh', 'The Mad Ghoul', 'Double Take', 'Running Target', 'Pennies from Heaven', 'Miracle in the Rain', 'The Shaggy D.A.', 'Hideout', 'Terror Tract', 'Theevram (തീവ്രം)', 'Iceman, TheThe Iceman', 'Sexy Evil Genius', "Talk Back and You're Dead", 'Night and the City', 'The Devil and Daniel Webster', "Winchester '73", 'Battlefield Baseball', 'Red Road', 'Enlighten Thy Daughter', 'The Dirty Picture', 'Odongo', 'The Messengers', 'The Great Mike', "City Slickers II: The Legend of Curly's Gold", 'Safe', 'Francis', 'Napoleon and Samantha', 'Neruppu Da', 'Lake of Dracula', 'Over the Brooklyn Bridge', 'The Rundown', 'Commandos Strike at Dawn', 'Afsana', 'Jumping for Joy', 'The Navigator: A Medieval Odyssey', 'Marutha Nattu Veeran', 'Maha Chor', 'Kasu Irukkanum', 'Social Register', 'Nine', 'Sky Lovers', 'Teenage Mutant Ninja Turtles III', 'Verum Pechu Alla', 'The Tenth Man', 'Moner Manush (film)', 'Banglar Nayok', 'Where the Red Fern Grows', 'C.I.D.', 'Anna and the King', 'Miss Conspirator', 'The Driller Killer', '12 Years a Slave', 'The Hundred-Year-Old Man Who Climbed Out the Window and Disappeared', 'Barefoot in the Park', 'Everyday I Love You', 'Aparichit', 'Romeo', 'City on Fire', 'Kuzhanthaikkaga', "Dilber'in Sekiz Günü", 'Return of the Pink Panther', 'Eight Crazy Nights', 'Deal', 'Out of Time', 'Man of the World', 'An Everlasting Piece', 'Kudiyirundha Koyil', 'A Fool There Was', 'Kavitha', 'Finders Keepers', 'Wild Bill', 'The Strangers', 'Legal Eagles', 'Irreconcilable Differences', 'Sidekicks', 'Fade to Black', 'Danny Collins', 'Jungle Moon Men', 'Born Lucky', 'Padithaal Mattum Podhuma', 'Sabapathy', 'Drip-Along Daffy', 'Zabak', 'Young and Dangerous 3', 'Jason and the Argonauts', 'India Speaks', 'Phantom of Chinatown', 'Star Appeal', 'Great Day in the Morning', 'Stop! Or My Mom Will Shoot',  ...

# %%
# Ejemplo de consulta 3
query = "time machine"
print("Películas encontradas:", search_manual_index(query, index))
# Out:
# Películas encontradas: {'Cooliekkaran', 'The Big Parade', 'The Guardian', 'ABBA: The Movie', 'Honey, I Blew Up the Kid', 'Minions', 'Gallipoli', 'Go Tell the Spartans', 'The Invisible Woman', 'Judge Dredd', 'Robot', 'Dust', 'Lost In Space', 'A Sound of Thunder', 'Feast of July', 'Dr. Who and the Daleks', ' Dressmaker, TheThe Dressmaker', 'One Hour Photo', 'Journey 2: The Mysterious Island', 'Poketto Monsutā Daiyamondo to Pāru Diaruga VS Parukia VS Dākurai', "Everybody's Fine", "Spirit of '76", 'Dark City', 'Dimension 5', 'Dragon Ball Z: Fusion Reborn', 'Charlotte Gray', 'Miracle Mile', 'The Secret of the Sword', 'Summer Time Machine Blues', 'Mysterians !The Mysterians', 'The Bridge at Remagen', 'The Amazing Transparent Man', 'Puppet Master X: Axis Rising', 'The Jackal', 'Easy Come, Easy Go', 'Indru Netru Naalai', 'Miracles', 'Dennis the Menace Strikes Again', 'Toy Soldiers', 'Paprika', 'Aliens in the Attic', 'Flags of Our Fathers', 'Metalstorm: The Destruction of Jared-Syn', 'Dead Leaves', 'The Great Mouse Detective', 'Time Bomb', 'The Triplets of Belleville (Les Triplettes de Belleville)', ' G-Force', 'Project Almanac', 'Sea of Sand', 'Birth', 'We Were Soldiers', 'Dead Heat', 'Soori', 'For Whom the Bell Tolls', 'Freejack', 'Unfaithful', 'Class of 1999', 'President', 'Letters from Iwo Jima', 'Santa Claus: The Movie', 'Be Forever Yamato', 'The Golden Compass', 'My Big Fat Greek Wedding', 'Auntie Mame', 'In Which We Serve', 'The Jetsons Meet the Flintstones', "Don't Cry, Nanking", 'Narasimha', 'Big', 'Tarzan and the Valley of Gold', 'Third Contact', 'Fatal Move', 'I, Robot', 'Hugo', 'Bachelorette', 'Mutiny on the Buses', 'The Legend of Hell House', 'Krrish', 'War Horse', 'Doraemon: Nobita and the Robot Kingdom', 'Young Sherlock Holmes', 'Manasaare', 'Idiocracy', 'Thunderbirds Are Go', 'Hotel for Dogs', 'White Palace', 'April and the Extraordinary World', 'Ernest Goes to Jail', 'Willy McBean and his Magic Machine', 'The Dancing Masters', 'Crank: High Voltage', 'The Long Voyage Home', 'The Imitation Game', 'Doraemon: The Records of Nobita, Spaceblazer', 'Black Sun: The Nanking Massacre', 'Black Butler: Book of the Atlantic', 'Cutting Class', "Brian's Song", 'Wilson', 'Ram Gopal Varma', 'The FBI Story', 'The Yankee Doodle Mouse', 'Castle Keep', 'Rockstar', 'Lone Wolf and Cub: Baby Cart to Hades', 'The Invisible Ray', 'Josie and the Pussycats', 'Protector, The', 'Designs on Jerry', 'The Iron Giant', 'Disclosure', 'Dark Water', 'Forever Young', "Doraemon: Nobita's Dinosaur", 'Aqua Teen Hunger Force Colon Movie Film for Theaters', 'Sun Vulcan Movie', "Mr. Bean's Holiday", ' Madea Goes to Jail', 'Passchendaele', 'Brick Bradford', 'Metro', 'Escape from Planet Earth', 'The Harry Hill Movie', 'Karvva', 'Battle for Terra', 'Bicentennial Man', 'Beep Prepared', 'Home of the Brave', 'Footloose', 'Tommy', 'Dragon Ball Z: Wrath of the Dragon', 'Manhunt', 'Dennis the Menace', 'D.A.R.Y.L.', 'Lucky', 'Heavy Traffic', 'Dr. Plonk', 'Stanley & Iris', 'Bounty Killer', 'Steins;Gate: Fuka Ryōiki no Déjà vu', 'Real Steel', 'The Amazing Praybeyt Benjamin', 'Dushman', 'The Sand Pebbles', 'Man of the Year', 'Howling III', 'Silent Movie', 'Mean Machine', 'Sour Grapes', 'Madhouse', 'The NeverEnding Story II: The Next Chapter', 'The Wars', 'Source Code', 'My Awkward Sexual Adventure', 'Grand Exit', 'The Bodyguard', 'Dino Time', 'Convoy', "The Pirates Who Don't Do Anything: A VeggieTales Movie", 'Punjab 1984', 'Grace Is Gone', 'Waltzes from Vienna', 'The Magnetic Monster', 'Our Own', 'They Gave Him a Gun', 'I Was an American Spy', 'First Blood', 'The Second Arrival', 'Spacehunter: Adventures in the Forbidden Zone', 'The Jerky Boys: The Movie', 'Think Like a Man Too', 'The Incredibles', 'The Secret Bride', 'Plunder & Lightning', 'Time Changer', 'Mr. Peabody & Sherman', 'Aditya 369', 'The Cable Guy', 'Terminator Salvation', 'Morocco', 'In the Line of Fire', 'Neelakasham Pachakadal Chuvanna Bhoomi', 'Maroko', 'The Witches', 'Snatch', '1983', 'ARQ', 'The Deserter', ...

# %%
# Ejemplo de consulta 3
query = "love"
print("Películas encontradas:", search_manual_index(query, index))
# Out:
# Películas encontradas: {'Tezz', 'The Matrix', 'Oscar and Lucinda', 'Bhoomi', 'Swing Your Lady', 'Daasi', 'Canyon Passage', 'Katha', 'Metropolis', 'Mayandi Kudumbathar', 'The Descendants', 'Fall in Love Like a Star', 'Bahurani', 'Vaajlaach Paahije - Game Ki Shinema', 'Escape from L.A.', 'Bhooloham', 'The Scar of Shame', 'Song of the Islands', 'Gaslight', 'Ramana, Kutty Radhika', 'My One and Only', 'Rainbow Song', 'Sufi Paranja Katha (സൂഫി പറഞ്ഞ കഥ )', ' The Haunted Mansion', "Brewster's Millions", 'Aayudham', 'The Evening Star', 'Thavamai Thavamirundhu', 'Woman of the Year', 'The Amati Girls', 'Jailhouse Rock', 'Trojan
u Veeran', 'Maha Chor', 'Kasu Irukkanum', 'Gangotri', "I've Heard the Mermaids Singing", 'Bujjigaadu', 'Nine', 'Sky Lovers', 'Breaking News', 'Teenage Mutant Ninja Turtles III', 'Verum Pechu Alla', 'Moner Manush (film)', 'Banglar Nayok', 'C.I.D.', 'Anna and the King', 'Off Track', 'The Sisterhood of the Traveling Pants 2', 'Jack Ahoy', 'Soho Incident', 'Ammo Bomma', 'Everyday I Love You', 'Barefoot in the Park', 'Believe Me, Xantippe', 'Romeo', 'Maine Pyar Kiya', 'Aparichit', 'City on Fire', 'Kuzhanthaikkaga', 'City of Damnation', 'Bernardine', 'Suzhou River', 'Moonnamathoral', "The Astronaut's Wife", 'Man of the World', 'Dharam Veer', 'Kavitha', 'Hare Kanch Ki Chooriyan', 'Wild Bill', 'Goodbye, Mr. Chips', 'From Justin to Kelly', 'Impact', 'Irreconcilable Differences', 'Hatim Tai', 'Fade to Black', 'Just Math Mathalli', 'Tujhe Meri Kasam', 'Calcu ...

# %%
# Configuración del índice con Whoosh
schema = Schema(Title=TEXT(stored=True), Plot=TEXT(stored=True))
if not os.path.exists("indexdir2"):
    os.mkdir("indexdir2")

ix = create_in("indexdir2", schema)
writer = ix.writer()

# Agregar documentos al índice
for _, row in data.iterrows():
    writer.add_document(Title=row['Title'], Plot=row['Plot'])
writer.commit()

# Consultas en el índice de Whoosh
with ix.searcher() as searcher:
    query = QueryParser("Plot", ix.schema).parse("love")
    results = searcher.search(query)
    for result in results:
        print(result['Title'])
# Out:
# Azhagai Irukkirai Bayamai Irukkirathu
# Hai Ram Charan
# Orange
# Neenade Naa
# Innisai Mazhai
# Kodanda Ramudu
# Iru Mugan
# Strange Magic
# Pooveli
# Dil Vil Pyar Vyar

# %%
# Crear el índice en Whoosh
schema = Schema(Title=TEXT(stored=True), Plot=TEXT(stored=True))
if not os.path.exists("indexdir3"):
    os.mkdir("indexdir3")

ix = create_in("indexdir3", schema)
writer = ix.writer()

# Agregar documentos al índice
for _, row in data.iterrows():
    writer.add_document(Title=row['Title'], Plot=row['Plot'])
writer.commit()

# Función de búsqueda en Whoosh con un límite dinámico
def search_whoosh_index(query, index_dir="indexdir3", limit=None):
    from whoosh.index import open_dir
    ix = open_dir(index_dir)
    with ix.searcher() as searcher:
        query = QueryParser("Plot", ix.schema).parse(query)
        results = searcher.search(query, limit=limit)
        return [result['Title'] for result in results]

# Comparar resultados entre el índice invertido manual y Whoosh
query = "man"

# Búsqueda en índice invertido manual
manual_results = search_manual_index(query, index)
print("Resultados del índice invertido manual:", manual_results)

# Búsqueda en Whoosh
whoosh_results = search_whoosh_index(query, limit=len(manual_results))
print("Resultados en Whoosh:", whoosh_results)
# Out:
# Resultados del índice invertido manual: {'Malice', 'The Matrix', 'River of No Return', 'The Awaken Punch', 'Daasi', 'Canyon Passage', 'Katha', 'Metropolis', 'The Brave', 'Bahurani', 'Dahleez', 'Passage to Marseille', 'Go Tell the Spartans', 'Boy on a Dolphin', 'Parda Hai Parda', 'Frankenstein Meets the Wolf Man', 'Gaslight', 'My One and Only', "Brewster's Millions", 'The Man Is Armed', 'Life During Wartime', 'The Evening Star', 'The Birdcage', 'The Reivers', 'Jailhouse Rock', 'Trojan War', 'The Little Convict', 'Captain Ron', 'Chill Factor', 'Vaastav: The Reality', ' Love of My Life', 'Miss You Like Crazy', 'War on Everyone', 'Cool Hand Luke', 'Flaming Feather', 'Texas Carnival', 'Norwegian Wood', 'Dance, Girl, Dance', 'Chitra', 'The Old Maid', 'My Young Auntie', 'Ardhangi', 'Actress', 'Comedy, TheThe Comedy', ' Berlin Syndrome', 'Immortal Sergeant', 'Enduring Love', 'So Long Mr. Chumps', 'Casual Sex?', 'Courier Boy Kalyan', 'The First Born', 'Waaris', 'Dedh Ishqiya', 'Catacombs', 'Mutiny on the Bounty', 'Kung Fu Hustle', 'Shukriya: Till Death Do Us Apart', 'Frozen Ground, TheThe Frozen Ground', 'Metalstorm: The Destruction of Jared-Syn', 'Apparition, TheThe Apparition', 'Kan Simittum Neram', 'West of Shanghai', 'The Magic Riddle', 'Broken Strings', 'Bus Stop', 'Vaana', "Love's Brother", 'Sirens', 'With Honors', 'Her Right to Live', 'Seepeeyan', 'In Love and War', 'Looking for Mr. Goodbar', 'Chained Heat II', 'Highway', 'Margin for Error', 'Crouching Tiger, Hidden Dragon: Sword of Destiny', 'Circus World', 'War Arrow', 'Confession of Murder (a.k.a. Memoirs of a Murderer)', 'Chakra', 'Gejje Pooje', 'Thoroughly Modern Millie', 'Patita', 'I Was a Teenage Werewolf', 'City Under Siege', 'The Phantom Tollbooth', 'Untamed', 'Potugadu', "Straight A's", 'Billy the Kid and the Green Baize Vampire', 'Fifty Roads to Town', 'Dus Kahaniyaan', 'The Road to Sampo', 'The Reluctant Fundamentalist', 'Joshilaay', 'Creepshow 2', 'Aadavantha Deivam', 'The Scorpion King', 'Nurse 3D', 'Vellimoonga', "You Can't Buy Everything", 'The Silver Lining', 'War, Inc.', 'Nalla Kaalam Porandaachu', 'No Retreat, No Surrender 2', 'The Savages', 'Munna Bhai M.B.B.S.', 'Pacific Destiny', 'Himalaya Singh', 'The Mad Ghoul', 'Double Take', 'Running Target', 'Pennies from Heaven', 'Miracle in the Rain', 'The Shaggy D.A.', 'Hideout', 'Terror Tract', 'Theevram (തീവ്രം)', 'Iceman, TheThe Iceman', 'Sexy Evil Genius', "Talk Back and You're Dead", 'Night and the City', 'The Devil and Daniel Webster', "Winchester '73", 'Battlefield Baseball', 'Red Road', 'Enlighten Thy Daughter', 'The Dirty Picture', 'Odongo', 'The Messengers', 'The Great Mike', "City Slickers II: The Legend of Curly's Gold", 'Safe', 'Francis', 'Napoleon and Samantha', 'Neruppu Da', 'Lake of Dracula', 'Over the Brooklyn Bridge', 'The Rundown', 'Commandos Strike at D
Baize Vampire', 'Faster, Pussycat! Kill! Kill!', 'Star Appeal', 'Baazi', 'For Her Sake', 'Lost Highway', 'Getting Played', 'Kaun', 'Anguish', 'Cicak Man 3', 'Draftee Daffy', 'The Old Man and the Sea', 'Yawm Said (Happy Day)', 'Raw Wind in Eden', 'Maaman Magal (1955 film)', 'The Bad Batch', 'Frog Dreaming', 'Les Bicyclettes de Belsize', 'S. J. Surya, Simran, Devayani, Kiran', 'Naani', 'Teenage Cave Man', 'The Trespasser', 'Lady Oscar', 'Mahakshathriya', 'Gun Woman', 'The Big Clock', 'The Neanderthal Man', 'Dark City', 'The Limping Man', 'The Committee', 'Miss Frontier Mail', 'Freebie and the Bean', 'Windows', 'Under the Skin', 'The Grandmaster', 'Uthami Petra Rathinam', 'The Golden Key', 'Parallel Sons', 'A Man and A Woman', 'Purge, TheThe Purge', 'Whispering City', 'Cheriya Kallanum Valiya Policum ( ചെറിയ കള്ളനും വലിയ പോലീസും )', 'Zakhmi Sher', 'Welcome to Hard Times', 'Two Can Play That Game', 'The Dark Man', 'The Good Father', 'Kannamma En Kadhali', 'Thathayya Premaleelalu', 'Castle of Sand', 'Dynamite Brothers', 'Gauri Ganesha', 'Tuck Everlasting', 'Modern Man', 'Thunderground', 'Khulood (Immortality)', 'The Sphinx', 'Diary ng Panget', 'The Sound of Fury', 'Tennessee Champ', 'Change of Mind', 'Velvet Smooth', 'Devta', ' The Next Best Thing', 'The Playboy of the Western World', 'Hob wa Dumoo` (Love and Tears)', 'Pardesi', 'Rangarattinam', 'Five Senses of Eros', 'Meshes of the Afternoon', 'Cool Breeze', 'Nightmare Man', 'Champagne', 'Meet Boston Blackie', 'Dangerous Number', 'Boom!', '3 Deewarein', 'Government Mappillai', 'The Lineup', 'A Tale of Two Cities', 'Oru Viral', 'Phantasm', 'Local Color', 'The Silver Lining', 'Edge of Doom', 'Her Minor Thing', 'Leave Me Alone', 'Aagaman', 'Unnal Mudiyum Thambi', "Mabel's Married Life", '7 Grandmasters', 'Wackiki Wabbit', 'Up in Smoke', 'Mud', 'The Joy Girl', 'Timeslip', 'The Final Judgement', 'Illegal', "Things to Do in Denver When You're Dead", 'The Haunted Bedroom', 'The Thin Man', 'Secret of the Blue Room', 'Salute the Toff', 'Kaviyam', 'Carnival of Souls', 'Koma', 'Thutturi', 'Time of Love', 'Ittefaq', 'A Ghost Story', 'Predestination', 'Berth Marks', 'Seepeeyan', 'Ride a Violent Mile', 'Swaroopam', 'Ranuva Veeran', 'Maamiyar Veedu', 'In Again, Out Again', 'Holidays with Pay', 'Return of a Stranger', 'Daera', 'Avittam Thirunaal Aarogya Sriman', 'Megamind', 'Dreams That Money Can Buy', 'Singam Puli', 'Young Dr. Kildare', 'The Wedding Ringer', 'Fore Play', 'Chinna Mapillai', 'Kyu-chan no Dekkai Yume', 'Night Fishing', 'Tunnel 3D', 'Chalte Chalte', 'Thalai ...
